# %% [markdown]
# # Lab 08: IA Generativa - VAE y GAN
#
# Introducción a modelos generativos.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

import sys
sys.path.append('codigo/')
from generativo import *

# %matplotlib inline

# %% [markdown]
# ## Parte 1: Variational Autoencoder (VAE)

# %%
entrenar_vae()

# %% [markdown]
# ## Parte 2: GAN Conceptual

# %%
demo_gan()

# %% [markdown]
# ## Conceptos Clave
#
# ### VAE:
# - Encoder: X → z (espacio latente probabilístico)
# - Decoder: z → X' (reconstrucción)
# - Loss = Reconstruction + KL Divergence
#
# ### GAN:
# - Generator: ruido → imagen
# - Discriminator: imagen → real/fake
# - Entrenamiento adversarial
#
# ### Aplicaciones:
# - Generación de imágenes
# - Texto (ChatGPT)
# - Arte y diseño
# - Descubrimiento de fármacos

# %% [markdown]
# ## Para Profundizar
#
# Usa PyTorch o TensorFlow para implementaciones completas:
#
# ```python
# # PyTorch VAE
# import torch
# import torch.nn as nn
#
# class VAE(nn.Module):
#     def __init__(self, input_dim, latent_dim):
#         super().__init__()
#         # Encoder
#         self.fc1 = nn.Linear(input_dim, 128)
#         self.fc_mu = nn.Linear(128, latent_dim)
#         self.fc_logvar = nn.Linear(128, latent_dim)
#         # Decoder
#         self.fc3 = nn.Linear(latent_dim, 128)
#         self.fc4 = nn.Linear(128, input_dim)
#
#     def encode(self, x):
#         h = torch.relu(self.fc1(x))
#         return self.fc_mu(h), self.fc_logvar(h)
#
#     def reparameterize(self, mu, logvar):
#         std = torch.exp(0.5 * logvar)
#         eps = torch.randn_like(std)
#         return mu + eps * std
#
#     def decode(self, z):
#         h = torch.relu(self.fc3(z))
#         return torch.sigmoid(self.fc4(h))
#
#     def forward(self, x):
#         mu, logvar = self.encode(x)
#         z = self.reparameterize(mu, logvar)
#         return self.decode(z), mu, logvar
# ```

# %% [markdown]
# ## ¡Felicitaciones! 🎉
#
# Has completado el curso de **Redes Neuronales desde Cero**.
#
# Ahora entiendes:
# - ✓ Fundamentos de redes neuronales
# - ✓ Forward y backward propagation
# - ✓ Funciones de activación y pérdida
# - ✓ Entrenamiento y optimización
# - ✓ Frameworks modernos
# - ✓ IA Generativa
#
# **¡Sigue aprendiendo y construyendo! 🚀**
